# %% [markdown]
# # Output Breakdown

# %% [markdown]
# The title:

# %% [markdown]
# ![title.png](data:image/png;base64,...)

# %% [markdown]
# The dropdown:

# %% [markdown]
# ![dropdown_1.png](data:image/png;base64,...)

# %% [markdown]
# ![dropdown_2.png](data:image/png;base64,...)

# %% [markdown]
# The pie chart:

# %% [markdown]
# ![pie_chart_1.png](data:image/png;base64,...)

# %% [markdown]
# ![pie_chart_2.png](data:image/png;base64,...)

# %% [markdown]
# ![pie_chart_3.png](data:image/png;base64,...)

# %% [markdown]
# ![pie_chart_4.png](data:image/png;base64,...)

# %% [markdown]
# ![bar_chart_5.png](data:image/png;base64,...)

# %% [markdown]
# The slider:

# %% [markdown]
# ![slider.png](data:image/png;base64,...)

# %% [markdown]
# ![scatter_plot_1.png](data:image/png;base64,...)

# %% [markdown]
# ![scatter_plot_2.png](data:image/png;base64,...)

# %% [markdown]
# ![scatter_chart_3.png](data:image/png;base64,...)

# %% [markdown]
# ![scatter_chart_4.png](data:image/png;base64,...)

# %% [markdown]
# ![scatter_chart_5.png](data:image/png;base64,...)

# %% [markdown]
# # Finding Insight Visually

# %% [markdown]
# ## Insight 1: Which site has the largest successful launches?

# %% [markdown]
# ![insight_1.png](data:image/png;base64,...)

# %% [markdown]
# Launch site KSC LC-39A has the largest successful launches.

# %% [markdown]
# ## Insight 2: Which site has the highest launch success rate?

# %% [markdown]
# ![insight_2.png](data:image/png;base64,...)

# %% [markdown]
# Launch site KSC LC-39A has the highest success rate.

# %% [markdown]
# ## Insight 3: Which payload range(s) has the highest launch success rate?

# %% [markdown]
# ![insight_3.png](data:image/png;base64,...)

# %% [markdown]
# Payload ranges 2k-4k has the highest success rate.

# %% [markdown]
# ## Insight 4: Which payload range(s) has the lowest launch success rate?

# %% [markdown]
# ![insight_4.png](data:image/png;base64,...)

# %% [markdown]
# It is hard to find which payload range(s) has the lowest launch success rate based on the scatter plot.

# %% [markdown]
# ## Insight 5: Which F9 Booster version (`v1.0`, `v1.1`, `FT`, `B4`, `B5`, etc.) has the highest success rate?

# %% [markdown]
# ![insight_5.png](data:image/png;base64,...)

# %% [markdown]
# FT Booster has the highest success rate.
